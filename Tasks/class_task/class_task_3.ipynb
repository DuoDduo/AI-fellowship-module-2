# %% [markdown]
# ## **Class Task 3** ##

# %% [markdown]
# **Given the following matrices**
#
# ```
# A = [2  -1]
#     [0   3]
# ```
#
#
# ```
# B = [1    4]
#     [-2    5]
# ```
#
# ```
# scalars - (c = 2, d = 3)
# ```

# %% [markdown]
# **A. Compute the following**
#
#
# ```
#         (cA) = 2 [2     -1]     = [(2x2)  (2x-1)]       = [4    -2]
#                  [0      3]       [(2x0)   (3x2)]       = [0     6]
#
#
#         (dB) = 3 [1      4]     = [(1x3)    (4x3)]       = [3     12]
#                  [-2     5]       [(-2x3)   (5x3)]       = [-6    15]
#
#
#         (c + d)A = (2 + 3)A  =  2A + 3A  =   [2  -1]  + 3[2  -1] = [(2x2) (2x-1)] [(3x2)(3x-1)]
#                                              [0   3]     [0   3]   [(2x0) (3x2)]  [(3x0)+(3x3)]
#
#
#         cA + dA =   [4  -2]     +   [6  -3]     =       [10     -5]
#                     [0   6]         [0   9]             [0      15]
#
# ```

# %% [markdown]
# **B. Using the result given , verify the scalar multiplication properties**
#
# - Properties of scalar multiplication
#   ```
#    - Associativity of Scalar Multiplication:
#    ```
#          (c.d)A =  c.(dA)
#
#              (c.d)A => (2 x 3)[2 -1] = 6[2 -1]  = [(6 x 2)  (6 x -1)]  =  [12  -6]
#                               [0  3]    [0  3]    [(6 x 0)  (6 x  3)]     [0   18]
#
#               c(dA) => 2 [(3 x 2)    (3 x -1)]  = 2 x [6   -3] =  [12  -6]
#                          [(3 x 0)    (3 x 3)]         [0    9]    [0   18]
#
#
#     - Distributivity over Matrix Addition:
#         c (A + B)=  cA + cB
#
#             c(A + B) => 2 [2  -1]  +  2[1  4]  =  [(2 x 2)  (2 x -1)] + [(2 X 1)   (2 X 4)]
#                           [0   3]      [-2  5]     [(2 x 0)  (2 x 3)]   [(2 X -2)   (2 X 5)]
#
#             cA + cB => [4  -2]   + [2    8] =  [6   6]
#                        [0   6]     [-4  10]    [-4  16]
#
#
#
#
#      - Distributivity over scalar addition :
#         (c + d)A =  cA + dA
#
#            (2 + 3)[2  -1] =  2[2  -1]  + 3[2  -1]
#                   [0   3]     [0   3]      [0  3]
#
#                   5[2  -1]  = [4   -2]   + [6  -3]
#                    [0   3]    [0   -6]     [0   9]
#
#                    [10   -5] = [10   -5]
#                    [0    15]   [0    15]

# %% [markdown]
# **C. Find the transpose of both matrices**
#  ```
# A = [2  -1]    =>   A^T =  [2    0]
#     [0   3]                [-1   3]
# ```
#
#
# ```
# B = [1    4]   =>  B^T  =  [1    -2]
#     [-2   5]               [4     5]
# ```

# %% [markdown]
# **C. Check if (A) and (B) are invertible by computing their determinants.**
# - If they are invertible,
# - find: A ^ - 1 and B ^ - 1
#
#
#     ```
#     A = [2  -1]
#         [0   3]
#     ```
#
#
#     ```
#     B = [1    4]
#         [-2    5]
#     ```
#
#    - Determinant of A:
#         ```
#         A = [2  -1]    =>  det(A)=  (2 X 3) - (-1 x 0)   det(A) = 6 - 0
#             [0   3]
#
#         det(A)= 6 (Hence it is invertible)
#
#         ```
#
#     - Inverse of A:
#         ```
#         A^-1 =>  1/6  = [3   1] = [3/6   1/6]  =  [1/2    1/6]
#                         [0   2]   [0     2/6]     [0      1/3]
#
#         ```
#
#     - Determinant of B:
#
#         ```
#         B = [1    4]   =>  =>  det(B)=  (1 X 5) - (4 x -2)   det(B) = 5 - (-8) = 5 + 8
#             [-2    5]
#
#         det(B)= 13 (Hence it is invertible)
#         ```
#
#     - Inverse of B:
#         ```
#         B^-1 =>  1/13  = [5   -4] = [5/13   -4/13]
#                          [2    1]   [2/13    1/13]
#
#         ```
