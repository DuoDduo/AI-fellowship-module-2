# %% [markdown]
# ## **Exploratory Data Analysis** ##

# %% [markdown]
# **Importing the libraries for EDA**

# %%
import pandas as pd
import os
import openpyxl
import matplotlib as plt
import seaborn as sns

# %%
# Load the dataset
sales = pd.read_csv("sales_data.xls")

# Display the data
sales

# Check the data types of each column
sales.dtypes
# Out:
# customer_id        object
# device_id          object
# item_id             int64
# line_item_id        int64
# order_id           object
# event_id            int64
# event_timestamp    object
# quantity            int64
# currency           object
# checked_out_at     object
# status             object
# location           object
# dtype: object

# %%
# Checking for missing values in the data set
sales.isna().sum()
sales.isnull().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
# checking the shape of the dataframe
sales.shape
# Out:
# (578320, 12)

# %%
# checking for duplicate values in the dataset
sales.duplicated().sum()
sales
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
# Resetting the index- method 1
sales.index = range(1, len(sales) + 1)
sales
# Resetting the index- method 2(Indexing the dataset)
sales_data = pd.DataFrame(sales, columns=sales.columns, index=range(1, len(sales) + 1))
sales_data
# Out:
#                                  customer_id  \
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# 5       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578320  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 1       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 2       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 3       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 4       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 5       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
#  this code will print the first 5 rows of customer_id, device_id and item_id columns
# [0, 2 , 4, 6]
sales_data.loc[[1, 2 , 4, 6]]
# Out:
#                             customer_id                             device_id  \
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 1        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6       11          3206  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#               event_timestamp  quantity currency              checked_out_at  \
# 1  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# ...

# %%
# Using loc to print the index of these columns
sales_data.loc[0:5, ["customer_id", "device_id", "item_id"]]
# Out:
#                             customer_id                             device_id  \
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 5  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 1        4
# 2        5
# 3        9
# 4       12
# 5        6

# %%
#setting the index column of the dataset to location
sales.set_index("location", inplace = True)
sales
# Out:
#                                            customer_id  \
# location
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena      cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Saint Helena      33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena      33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# ...

# %%
# Display the first five elements in the dataset
sales.head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
# this prints out the index of the dataframe which is set as the location column
sales.index
# Out:
# Index(['Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena',
#        ...
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island'],
#       dtype='object', name='location', length=578320)

# %%
# Displaying the list of unique locations with customers
unique_locations_index = sales.index.unique().sort_values()
print(f"These are the unique customer locations:\n{unique_locations_index}")
# Out:
# These are the unique customer locations:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica (the territory South of 60 deg S)',
#        'Antigua and Barbuda', 'Argentina',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location', length=243)

# %% [markdown]
# ## `Data Visualization of top 10 locations with the most sales using pandas bar chart`

# %%
# Checking the number of customer locations that are unique
unique_locations = sales.index.nunique()
print(f"Total number of unique locations is {unique_locations}")
# Out:
# Total number of unique locations is 243

# %%
# this checks the top 10 locations with highest sales
sales.index.value_counts().head(10)
print(f"The top 10 locations with highest sales are {sales.index.value_counts().head(10)}")
# Out:
# The top 10 locations with highest sales are location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
# A barchart of the top ten locations with highest sales
top_ten_sales= sales.index.value_counts().head(10).plot(kind = "bar", color = "green", title = "Top 10 locations with highest sales")

# %% [markdown]
# ## `Data Visualization of last 10 locations with the lowest sales using pandas`

# %%
# this checks the last 10 locations with lowest sales
sales.index.value_counts().tail(10)
print(f"The least 10 locations with lowest sales are {sales.index.value_counts().tail(10)}")
# Out:
# The least 10 locations with lowest sales are location
# Greece                     1214
# Saint Kitts and Nevis      1201
# Honduras                   1195
# Cocos (Keeling) Islands    1168
# Taiwan                     1122
# Chad                       1082
# Malaysia                   1037
# Austria                     921
# Italy                       783
# Uruguay                     734
# Name: count, dtype: int64

# %%
# plotting the barchart for the last 10 locations with the least sales
ten_least_sales= sales.index.value_counts().tail(10).plot(kind = "bar", color = "red", title = "10 locations with the least sales")

# %% [markdown]
# ## `Filtering and Data Visualization of top 50 locations with the highest sales using pandas`

# %%
# this checks the top 10 locations with highest sales
top_fifty_sales= sales.index.value_counts().head(50)
print(f"The top 50 locations with highest sales are {top_fifty_sales}")
# Out:
# The top 50 locations with highest sales are location
# Korea                          6997
# Argentina                      4507
# Mauritius                      4414
# Jersey                         4130
# Panama                         3936
# French Guiana                  3851
# Guernsey                       3804
# Guatemala                      3731
# Albania                        3721
# Philippines                    3675
# Mali                           3670
# Congo                          3642
# Finland                        3615
# Cape Verde                     3509
# Christmas Island               3471
# China                          3429
# France                         3425
# French Southern Territories    3421
# Poland                         3355
# Cyprus                         3345
# Switzerland                    3342
# British Virgin Islands         3329
# Bosnia and Herzegovina         3309
# Niger                          3295
# ...

# %% [markdown]
# `Data visualization of top fifty locations with most sales using barchart in pandas`

# %%
# top 50 locations where most patronage are recieved
top_fifty_sales= sales.index.value_counts().head(50).plot(kind = 'bar',figsize = (20,20), title='Top 50 locations with the most sales')

# %% [markdown]
# ## `Filtering and Data Visualization of the bottom 50 locations with the least sales using pandas`

# %%
# this checks the last 50 locations with lowest sales
fifty_least_sales= sales.index.value_counts().tail(50)
print(f"The Last 50 locations with the least sales are: {fifty_least_sales}")
# Out:
# The Last 50 locations with the least sales are: location
# Falkland Islands (Malvinas)                     1743
# Angola                                          1742
# Ghana                                           1735
# Bulgaria                                        1733
# Benin                                           1727
# Denmark                                         1720
# India                                           1712
# Aruba                                           1712
# French Polynesia                                1695
# Ireland                                         1689
# Burkina Faso                                    1683
# American Samoa                                  1682
# Antarctica (the territory South of 60 deg S)    1674
# Micronesia                                      1666
# Spain                                           1665
# Sudan                                           1662
# Vanuatu                                         1638
# ...

# %% [markdown]
#  `A chart of the least 50 locations with the lowest number of purchase`

# %%
# Least 50 locations where patronage are recieved
fifty_least_sales= sales.index.value_counts().tail(50).plot(kind = 'bar',figsize = (20,20), title='Last 50 locations with the least sale', color="red")

# %% [markdown]
# ## Section ##

# %%
# checking the number of columns in the dataset
column_length= len(sales.columns)
print(f"The number of columns in the dataset is {column_length}")
# Out:
# The number of columns in the dataset is 11

# %%
# Displaying a specific location using loc (label)
find_location = sales.loc["Vietnam"]
find_location
# Out:
#                                    customer_id  \
# location
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# Vietnam   ccacbe4d-535b-4e77-bbb7-5ba7c203bd41
# ...                                        ...
# Vietnam   80856f71-570c-4b1d-9704-bf82b2c954bf
# Vietnam   80856f71-570c-4b1d-9704-bf82b2c954bf
# Vietnam   80856f71-570c-4b1d-9704-bf82b2c954bf
# Vietnam   80856f71-570c-4b1d-9704-bf82b2c954bf
# Vietnam   80856f71-570c-4b1d-9704-bf82b2c954bf
#
#                                      device_id  item_id  line_item_id  \
# location
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       14          4249
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac       13          4250
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        1          4251
# Vietnam   cfcd37ea-077d-4d19-8427-b7864abcabac        8          4252
# ...

# %%
# Displaying locations using the iloc(index): printing rows from index 4000 to the end of the dataset
find_location_index = sales.iloc[4000:]
find_location_index
# Out:
#                                            customer_id  \
# location
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# Poland            0b1d359b-6e85-4f42-86bb-3e3675e4bf47
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Poland            4ae11055-6894-4298-b258-9b57deee8962       12          3416
# Poland            4ae11055-6894-4298-b258-9b57deee8962       10          3417
# ...

# %% [markdown]
# ## Filtering the sales data using customer_id ##

# %%
# setting the id_customer to a specific id
id_customer = sales[sales['customer_id'] == "cda7bec0-7cbf-4145-baf9-e049bab94504"]
id_customer
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                            ...
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# ...

# %%
# resetting the event_timestamp to date time format
dates = pd.to_datetime(sales["event_timestamp"])
dates

# date_ = pd.to_datetime(sales["event_timestamp"]).dt.date
# date_
# Out:
# location
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
# Saint Helena       2024-03-26 22:05:58.863661
#                               ...
# Christmas Island   2024-03-30 04:03:18.224196
# Christmas Island   2024-03-30 04:03:18.224198
# Christmas Island   2024-03-30 04:03:18.224198
# Christmas Island   2024-03-30 04:14:18.224200
# Christmas Island   2024-03-30 04:14:18.224200
# Name: event_timestamp, Length: 578320, dtype: datetime64[ns]

# %%
# checking the number of unique customers
total_no_of_customers = sales["customer_id"].nunique()
print(f"The total number of unique customers: {total_no_of_customers}")
# Out:
# The total number of unique customers: 4594

# %% [markdown]
# ## `Data Visualization of top 20 customers with the highest purchase using pandas barchart`

# %%
# Top 20 custommers with the highest purchases....
top_20= sales["customer_id"].value_counts().head(25).sort_values(ascending = False).head(20).plot(kind="bar", figsize= (15, 15),title="Top 20 customers with the highest purchase", color = "purple")
print(f"Below are the top twenty customers with the highest purchases\n{top_20}")
# Out:
# Below are the top twenty customers with the highest purchases
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Masking ##

# %%
# Using a particular customer_info for masking
mask = (sales["customer_id"] == "ebcb2343-be1b-421e-83eb-6f79a321d999")

# %%
# Checking customer behaviour
customer_behaviour = sales[mask].head(5)
customer_behaviour
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        4
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        9
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        2
#
#                    line_item_id                              order_id  \
# location
# Wallis and Futuna         26108  5984596b-0ed5-4571-8e79-b261e6f138ad
# ...

# %%
# Checking the customer behaviour using loc 
sales.loc[mask].head(5)
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        4
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        9
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        2
#
#                    line_item_id                              order_id  \
# location
# Wallis and Futuna         26108  5984596b-0ed5-4571-8e79-b261e6f138ad
# ...

# %%
# Masking the customer_id against the currency
sales.loc[mask,"customer_id":"currency"].head(2)
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
#
#                    line_item_id                              order_id  \
# location
# Wallis and Futuna         26108  5984596b-0ed5-4571-8e79-b261e6f138ad
# Wallis and Futuna         26109  5984596b-0ed5-4571-8e79-b261e6f138ad
#
#                    event_id             event_timestamp  quantity currency
# location
# Wallis and Futuna    121373  2024-03-27 12:43:53.991103         5      NGN
# Wallis and Futuna    121373  2024-03-27 12:43:53.991103         1      NGN

# %% [markdown]
# ## Currency ##

# %%
# Checking the unique currencies in the dataset
currencies = sales['currency'].unique()
no_currencies = sales['currency'].nunique()
print(f"The dataset has a total number of {no_currencies} unique currencies which are {currencies}")
# Out:
# The dataset has a total number of 3 unique currencies which are ['NGN' 'USD' 'GBP']

# %%
# Number of times the currencies were used 
currency_usage = sales['currency'].value_counts()
print(f"Total number of times the {currencies} were used:\n{currency_usage}")
# Out:
# Total number of times the ['NGN' 'USD' 'GBP'] were used:
# currency
# USD    198037
# GBP    191403
# NGN    188880
# Name: count, dtype: int64

# %% [markdown]
# ## `Data visualization of the currencies used for purchase using pie chart in  Pandas`

# %%
# Plotting a pie chart to show the number of times a currency was used
currency_usage.plot(kind='pie', title='Currencies Used(USD, GBP, NGN)')
# Out:
# <Axes: title={'center': 'Currencies Used(USD, GBP, NGN)'}, ylabel='count'>

# %%
# Plotting a bar chart to show the number of times a currency was used
currency_usage.plot(kind ="bar" ,  figsize =(10, 10,) , title='Currencies Used(USD, GBP, NGN)', color = "green")
# Out:
# <Axes: title={'center': 'Currencies Used(USD, GBP, NGN)'}, xlabel='currency'>

# %% [markdown]
# ## Applying More Filters ##

# %%
# Using a particular customer_info for masking
mask = (sales["customer_id"] == "ebcb2343-be1b-421e-83eb-6f79a321d999")
mask
# Out:
# location
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
#                     ...
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Name: customer_id, Length: 578320, dtype: bool

# %%
# Selecting a customer with a successful transaction
mask2 = (sales['customer_id'] == "ebcb2343-be1b-421e-83eb-6f79a321d999") & (sales['status'] == 'success')
mask2
# Out:
# location
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
#                     ...
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Christmas Island    False
# Length: 578320, dtype: bool

# %%
# Checking the index of the customer with successful transactions
sucsess_customer_A = sales.loc[mask2]
sucsess_customer_A
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# ...                                                 ...
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        4
# ...

# %%
# checking the number of succesful transaction carried out by the selected customer (scuccess_customer_A)
success_customer_A = sales.loc[mask2]
no_of_purchase = success_customer_A['status'].value_counts
print(f"The list of successful transactions carried out by customer A is {no_of_purchase}")
# Out:
# The list of successful transactions carried out by customer A is <bound method IndexOpsMixin.value_counts of location
# Wallis and Futuna    success
# Wallis and Futuna    success
# Wallis and Futuna    success
# Wallis and Futuna    success
# Wallis and Futuna    success
#                       ...
# Wallis and Futuna    success
# Wallis and Futuna    success
# Wallis and Futuna    success
# Wallis and Futuna    success
# Wallis and Futuna    success
# Name: status, Length: 360, dtype: object>

# %%
# Filtering data set based on failed transactions
mask3 = (sales['status'] == 'failed')
mask3
# Out:
# location
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
# Saint Helena        False
#                     ...
# Christmas Island     True
# Christmas Island     True
# Christmas Island     True
# Christmas Island     True
# Christmas Island     True
# Name: status, Length: 578320, dtype: bool

# %%
# Checking the failed transactions in the dataset
failed_transaction = sales.loc[mask3]
failed_transaction
# Out:
#                                            customer_id  \
# location
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti          e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Mali              f40fc2b7-0a0f-46e8-8fc5-4edfa5eb832b
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti          428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# ...

# %%
# Transaction History Count
transaction_status = sales['status'].value_counts()
print(f"Below is the transaction status {transaction_status}")
# Out:
# Below is the transaction status status
# failed       196383
# success      192594
# cancelled    189343
# Name: count, dtype: int64

# %% [markdown]
# ## `Data visualization of the transactions using barchart in  Pandas`

# %%
# Plotting the bar chart of the transaction history showing the transaction tatuses

transaction_status.plot(kind = "bar", color= "blue", xlabel="Status", ylabel= "Transaction", title= "Transaction Status")
# Out:
# <Axes: title={'center': 'Transaction Status'}, xlabel='Status', ylabel='Transaction'>

# %% [markdown]
# ## Currency by status

# %%
# checking status of transaction by currency
currency_by_status = sales.groupby("currency")["status"].value_counts()
currency_by_status
# Out:
# currency  status
# GBP       cancelled    64324
#           success      64266
#           failed       62813
# NGN       success      66146
#           failed       65387
#           cancelled    57347
# USD       failed       68183
#           cancelled    67672
#           success      62182
# Name: count, dtype: int64

# %% [markdown]
# `Data visualization of the transactions using barchart in Pandas`

# %%
# Plotting a bar chart for the currency against the status using seaborn
currency_by_status.plot(kind = "bar", color= "black", xlabel="Currency", ylabel= "Status", title= "Status by Currency")
# Out:
# <Axes: title={'center': 'Status by Currency'}, xlabel='Currency', ylabel='Status'>

# %%
# Using a specified location for further wrangling
Djibouti = sales.loc["Djibouti"]
Djibouti.head(4)
# Out:
#                                    customer_id  \
# location
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
#
#                                      device_id  item_id  line_item_id  \
# location
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
#
#                                       order_id  event_id  \
# location
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14800
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14801
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14802
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14803
#
# ...

# %%
# Getting the information about the location Djibouti from the data set
Djibouti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1394 entries, Djibouti to Djibouti
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      1394 non-null   object
#  1   device_id        1394 non-null   object
#  2   item_id          1394 non-null   int64
#  3   line_item_id     1394 non-null   int64
#  4   order_id         1394 non-null   object
#  5   event_id         1394 non-null   int64
#  6   event_timestamp  1394 non-null   object
#  7   quantity         1394 non-null   int64
#  8   currency         1394 non-null   object
#  9   checked_out_at   1394 non-null   object
#  10  status           1394 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 130.7+ KB

# %%
# Checking the shape of the data
Djibouti.shape
Djibouti.shape[0]
# Out:
# 1394

# %% [markdown]
# Status of transaction in a specific country (Djibouti)

# %%
# finding out the status of transaction in Djibouti

failed_transc = Djibouti[Djibouti ["status"] == "failed"]
successful_transc = Djibouti[Djibouti ["status"] == "success"]
cancelled_transc = Djibouti[Djibouti ["status"] == "cancelled"]

# %%
# Checking the number of failed transactions in Djibouti
no_of_failed = failed_transc.shape[0]
print(f"The Number of failed transactions in Djibouti: {no_of_failed}")
# Out:
# The Number of failed transactions in Djibouti: 240

# %%
# Checking the number of succesful transactions in Djibouti
no_of_successful = successful_transc.shape[0]
print(f"The Number of successful transactions in Djibouti: {no_of_successful}")
# Out:
# The Number of successful transactions in Djibouti: 916

# %%
# Checking the number of cancelled transactions in Djibouti
no_of_cancelled = cancelled_transc.shape[0]
print(f"The Number of Cancelled transactions in Djibouti: {no_of_cancelled}")
# Out:
# The Number of Cancelled transactions in Djibouti: 553

# %%
# Number of  Customers that had failed transactions in Djibouti
no_failed_transc = failed_transc.customer_id.nunique()
no_failed_transc

print(f"The total number of unique customers that had a failed transaction in Djibouti: {no_failed_transc}")
# Out:
# The total number of unique customers that had a failed transaction in Djibouti: 6

# %%
# Customers that had failed transactions
id_failed_trans = failed_transc.customer_id.unique()
id_failed_trans
# Out:
# array(['e7f07fd1-05af-494a-ae5a-78c405b6f9c3',
#        '49a54a5f-a582-403d-b327-601dea39109e',
#        '01d9a9a7-1312-4c51-ad70-48247938c55b',
#        '22971454-987d-4270-ad77-a05ecb74c4c5',
#        '037a561d-c922-4d48-aea0-91db4ffa6e43',
#        '8160790a-66f3-412d-9844-d1f2d377d6c6'], dtype=object)

# %%
#checking the first failed transaction
status_cause = failed_transc.iloc[0]
status_cause
# Out:
# customer_id        e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# device_id          428688d6-31e6-4c73-a5d0-c8e849ccf6a3
# item_id                                               9
# line_item_id                                       3207
# order_id           cddddfea-27ef-437f-817d-8f849d604c3c
# event_id                                          14800
# event_timestamp              2024-03-19 19:06:51.166018
# quantity                                              3
# currency                                            NGN
# checked_out_at               2024-03-30 04:09:10.411149
# status                                           failed
# Name: Djibouti, dtype: object

# %%
# Selecting the id of the first failed transaction in Djibouti to understand the cause
e7f07fd1 = failed_transc[failed_transc['customer_id'] == "e7f07fd1-05af-494a-ae5a-78c405b6f9c3"]
e7f07fd1
# Out:
#                                    customer_id  \
# location
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
#
#                                      device_id  item_id  line_item_id  \
# location
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
#
#                                       order_id  event_id  \
# location
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14800
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14801
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14802
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14803
#
# ...

# %%
# The number of times the first customer experienced a failed transaction
no_of_failed_times= e7f07fd1.shape[0]
print(f"The customer experienced a total of {no_of_failed_times} failed transactions")

# e7f07fd1
# Out:
# The customer experienced a total number of 4 failed transactions

# %%
# Checking the currency the first customer using for the transaction
type_currency = e7f07fd1.currency.unique()
print(f"This customer carried out trnasaction in {type_currency}")
# Out:
# This customer carried out trnasaction in ['NGN']

# %%
#checking the second failed transaction  in Djibouti
second_cause = failed_transc.iloc[1]
second_cause
# Out:
# customer_id        e7f07fd1-05af-494a-ae5a-78c405b6f9c3
# device_id          428688d6-31e6-4c73-a5d0-c8e849ccf6a3
# item_id                                               9
# line_item_id                                       3207
# order_id           cddddfea-27ef-437f-817d-8f849d604c3c
# event_id                                          14801
# event_timestamp              2024-03-30 04:03:10.410889
# quantity                                              3
# currency                                            NGN
# checked_out_at               2024-03-30 04:09:10.411149
# status                                           failed
# Name: Djibouti, dtype: object

# %%
# Selecting the id of the first failed transaction in Djibouti to understand the cause
e7f07fd1 = failed_transc[failed_transc['customer_id'] == "e7f07fd1-05af-494a-ae5a-78c405b6f9c3"]
e7f07fd1.head(1)
# Out:
#                                    customer_id  \
# location
# Djibouti  e7f07fd1-05af-494a-ae5a-78c405b6f9c3
#
#                                      device_id  item_id  line_item_id  \
# location
# Djibouti  428688d6-31e6-4c73-a5d0-c8e849ccf6a3        9          3207
#
#                                       order_id  event_id  \
# location
# Djibouti  cddddfea-27ef-437f-817d-8f849d604c3c     14800
#
#                      event_timestamp  quantity currency  \
# location
# Djibouti  2024-03-19 19:06:51.166018         3      NGN
#
#                       checked_out_at  status
# location
# Djibouti  2024-03-30 04:09:10.411149  failed
