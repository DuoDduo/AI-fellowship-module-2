# %% [markdown]
# ## **Exploratory Data Analysis** ##

# %% [markdown]
# **Importing the libraries for EDA**

# %%
import pandas as pd
import os
import openpyxl
import matplotlib
import seaborn

# %%
# Load the dataset
sales = pd.read_csv("sales_data.xls")

# Display the data
sales

# Check the data types of each column
sales.dtypes
# Out:
# customer_id        object
# device_id          object
# item_id             int64
# line_item_id        int64
# order_id           object
# event_id            int64
# event_timestamp    object
# quantity            int64
# currency           object
# checked_out_at     object
# status             object
# location           object
# dtype: object

# %%
# Checking for missing values
sales.isna().sum()
sales.isnull().sum()
# Out:
# customer_id        0
# device_id          0
# item_id            0
# line_item_id       0
# order_id           0
# event_id           0
# event_timestamp    0
# quantity           0
# currency           0
# checked_out_at     0
# status             0
# location           0
# dtype: int64

# %%
# checking the shape of the dataframe
sales.shape
# Out:
# (578320, 12)

# %%
# checking for duplicate values
sales.duplicated().sum()
sales
# Out:
#                                  customer_id  \
# 0       cda7bec0-7cbf-4145-baf9-e049bab94504
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 0       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 1       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 2       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 3       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 4       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
# Resetting the index- method 1
sales.index = range(1, len(sales) + 1)
sales
# Resetting the index- method 2
sales_data = pd.DataFrame(sales, columns=sales.columns, index=range(1, len(sales) + 1))
sales_data
# Out:
#                                  customer_id  \
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 2       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 4       cda7bec0-7cbf-4145-baf9-e049bab94504
# 5       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578316  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578318  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578320  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 1       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 2       33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# 3       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 4       33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# 5       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# ...

# %%
#  this code will print the first 5 rows of customer_id, device_id and item_id columns
# [0, 2 , 4, 6]
sales_data.loc[[1, 2 , 4, 6]]
# Out:
#                             customer_id                             device_id  \
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 6  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id  line_item_id                              order_id  event_id  \
# 1        4          3201  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 2        5          3202  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 4       12          3204  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# 6       11          3206  9e950ce3-2e12-479c-a051-493c1a497d49     14786
#
#               event_timestamp  quantity currency              checked_out_at  \
# 1  2024-03-26 22:05:58.863661         2      NGN  2024-03-30 04:19:10.406794
# ...

# %%
# this code will print the first 5 rows of customer_id, device_id and item_id columns
sales_data.loc[0:5, ["customer_id", "device_id", "item_id"]]
# Out:
#                             customer_id                             device_id  \
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 2  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 5  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 1        4
# 2        5
# 3        9
# 4       12
# 5        6

# %%
# Indexing columns- this will print the first 5 rows and first 3 columns
sales_data.iloc[[ 0, 2, 3, 4], [0, 1, 2]]
# Out:
#                             customer_id                             device_id  \
# 1  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 3  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 4  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
# 5  cda7bec0-7cbf-4145-baf9-e049bab94504  33b485de-7338-4997-b1d0-b988ba17b245
#
#    item_id
# 1        4
# 3        9
# 4       12
# 5        6

# %%
# this prints all the rows and columns
sales.iloc[::]
# this prints every second row
sales.iloc[::2]
# Out:
#                                  customer_id  \
# 1       cda7bec0-7cbf-4145-baf9-e049bab94504
# 3       cda7bec0-7cbf-4145-baf9-e049bab94504
# 5       cda7bec0-7cbf-4145-baf9-e049bab94504
# 7       cda7bec0-7cbf-4145-baf9-e049bab94504
# 9       cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                      ...
# 578311  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578313  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578315  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578317  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# 578319  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                    device_id  item_id  line_item_id  \
# 1       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 3       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# 5       33b485de-7338-4997-b1d0-b988ba17b245        6          3205
# 7       33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# 9       33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# ...

# %%
#setting the index column of the dataset to location
sales.set_index("location", inplace = True)
sales.head()
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245       12          3204
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        6          3205
#
#                                           order_id  event_id  \
# location
# Saint Helena  9e950ce3-2e12-479c-a051-493c1a497d49     14786
# ...

# %%
# this prints out the index of the dataframe which is set as the location column
sales.index
# Out:
# Index(['Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena', 'Saint Helena', 'Saint Helena',
#        'Saint Helena', 'Saint Helena',
#        ...
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island', 'Christmas Island', 'Christmas Island',
#        'Christmas Island'],
#       dtype='object', name='location', length=578320)

# %%
# this prints the unique values of the index column which is location
unique_index = sales.index.unique().sort_values()
# this checks the number of unique customer locations in the location column
unique_locations_index = sales.index.nunique()
# this prints out the number of unique locations in the location column
print(f'The number of unique customer locations is {unique_locations_index} and they are {unique_index}')
# Out:
# The number of unique customer locations is 243 and they are Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antarctica (the territory South of 60 deg S)',
#        'Antigua and Barbuda', 'Argentina',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'Wallis and Futuna', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location', length=243)

# %%
# this checks the top 10 locations with highest sales
sales.index.value_counts().head(10)
# Out:
# location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
# this checks the top 10 locations with highest sales
sales.index.value_counts().head(10)
print(f"The top 10 locations with highest sales are {sales.index.value_counts().head(10)}")

# this checks the last 10 locations with lowest sales
sales.index.value_counts().tail(10)
print(f"The least 10 locations with lowest sales are {sales.index.value_counts().tail(10)}")
# Out:
# The top 10 locations with highest sales are location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64
# The least 10 locations with lowest sales are location
# Greece                     1214
# Saint Kitts and Nevis      1201
# Honduras                   1195
# Cocos (Keeling) Islands    1168
# Taiwan                     1122
# Chad                       1082
# Malaysia                   1037
# Austria                     921
# Italy                       783
# Uruguay                     734
# Name: count, dtype: int64

# %% [markdown]
# ## `Data Visualization of top 10 locations with the most sales using pandas`

# %%
# this checks the top 10 locations with highest sales
sales.index.value_counts().head(10)
print(f"The top 10 locations with highest sales are {sales.index.value_counts().head(10)}")
# Out:
# The top 10 locations with highest sales are location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
sales.index.value_counts().head(10).plot(kind = "bar", color = "green", title = "Top 10 locations with highest sales")
# Out:
# <Axes: title={'center': 'Top 10 locations with highest sales'}, xlabel='location'>

# %% [markdown]
# ## `Data Visualization of least 10 locations with the lowest sales using pandas`

# %%
# this checks the last 10 locations with lowest sales
sales.index.value_counts().tail(10)
print(f"The least 10 locations with lowest sales are {sales.index.value_counts().tail(10)}")
# Out:
# The least 10 locations with lowest sales are location
# Greece                     1214
# Saint Kitts and Nevis      1201
# Honduras                   1195
# Cocos (Keeling) Islands    1168
# Taiwan                     1122
# Chad                       1082
# Malaysia                   1037
# Austria                     921
# Italy                       783
# Uruguay                     734
# Name: count, dtype: int64

# %%
# plotting the chart for the last 10 locations with the least sales
sales.index.value_counts().tail(10).plot(kind = "bar", color = "orange", title = "10 locations with the least sales")
# Out:
# <Axes: title={'center': '10 locations with the least sales'}, xlabel='location'>

# %% [markdown]
# ## `Data Visualization of first 50 locations with the highest sales using pandas`

# %%
# this checks the top 10 locations with highest sales
sales.index.value_counts().head(50)
print(f"The top 50 locations with highest sales are {sales.index.value_counts().head(10)}")
# Out:
# The top 50 locations with highest sales are location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
# top 60 locations where most patronage are recieved
sales.index.value_counts().head(50).plot(kind = 'bar',figsize = (20,20), title='Top 50 locations with the most sale')
# Out:
# <Axes: title={'center': 'Top 50 locations with the most sale'}, xlabel='location'>

# %% [markdown]
# ## `Data Visualization of the bottom 50 locations with the least sales using pandas`

# %%
# this checks the top 10 locations with highest sales
sales.index.value_counts().tail(50)
print(f"The Last 50 locations with the least sales are {sales.index.value_counts().head(10)}")
# Out:
# The Last 50 locations with the least sales are location
# Korea            6997
# Argentina        4507
# Mauritius        4414
# Jersey           4130
# Panama           3936
# French Guiana    3851
# Guernsey         3804
# Guatemala        3731
# Albania          3721
# Philippines      3675
# Name: count, dtype: int64

# %%
# Least 50 locations where patronage are recieved
sales.index.value_counts().tail(50).plot(kind = 'bar',figsize = (20,20), title='Last 50 locations with the least sale', color="red")
# Out:
# <Axes: title={'center': 'Last 50 locations with the least sale'}, xlabel='location'>

# %% [markdown]
# ## Section ##

# %%
# checking the number of columns in the dataset
column_length= len(sales.columns)
print(f"The number of columns in the dataset is {column_length}")
# Out:
# The number of columns in the dataset is 11

# %%
# .loc in this instance is used to find the locations
# displaying all the sales data for Christmas Island
find_location = sales.loc["Christmas Island"]
find_location
# Out:
#                                            customer_id  \
# location
# Christmas Island  001c37e2-f25c-45c1-8326-1ddf73c21dde
# Christmas Island  001c37e2-f25c-45c1-8326-1ddf73c21dde
# Christmas Island  001c37e2-f25c-45c1-8326-1ddf73c21dde
# Christmas Island  001c37e2-f25c-45c1-8326-1ddf73c21dde
# Christmas Island  001c37e2-f25c-45c1-8326-1ddf73c21dde
# ...                                                ...
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island  ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
#                                              device_id  item_id  line_item_id  \
# location
# Christmas Island  78183678-dda0-48e6-9348-8c6c617a9fb4        9          3329
# Christmas Island  78183678-dda0-48e6-9348-8c6c617a9fb4       10          3330
# ...

# %%
# printing all the sales data from row 400 to the end of the dataset
sales.iloc[400 : ]
# Out:
#                                                                customer_id  \
# location
# United States Minor Outlying Islands  bacabc27-738e-43f3-bc44-e03f717a1710
# United States Minor Outlying Islands  bacabc27-738e-43f3-bc44-e03f717a1710
# United States Minor Outlying Islands  bacabc27-738e-43f3-bc44-e03f717a1710
# United States Minor Outlying Islands  bacabc27-738e-43f3-bc44-e03f717a1710
# United States Minor Outlying Islands  bacabc27-738e-43f3-bc44-e03f717a1710
# ...                                                                    ...
# Christmas Island                      ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island                      ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island                      ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island                      ef15a7b3-326c-405f-9eef-3dbf43c85a9d
# Christmas Island                      ef15a7b3-326c-405f-9eef-3dbf43c85a9d
#
# ...

# %% [markdown]
# ## Filtering the sales data using customer_id ##

# %%
# resetting the customer_id
sales[sales['customer_id'] == "cda7bec0-7cbf-4145-baf9-e049bab94504"]
# sales['new_customer_id'] = sales['customer_id']
# sales['customer_id'] = range(1, len(sales) + 1)
# sales["new_customer_id"]
# Out:
#                                        customer_id  \
# location
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# ...                                            ...
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
# Saint Helena  cda7bec0-7cbf-4145-baf9-e049bab94504
#
#                                          device_id  item_id  line_item_id  \
# location
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        4          3201
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        5          3202
# Saint Helena  33b485de-7338-4997-b1d0-b988ba17b245        9          3203
# ...

# %%
# resetting the event_timestamp to date only
sales["event_timestamp"] = pd.to_datetime(sales["event_timestamp"])

# date_ = pd.to_datetime(sales["event_timestamp"]).dt.date
# date_

# %%
# # total number of customers
# sales["new_customer_id"].nunique()
# print(f"The total number of unique customers is {sales['new_customer_id'].nunique()}")
# total number of customers
sales["customer_id"].nunique()
print(f"The total number of unique customers is {sales['customer_id'].nunique()}")
# Out:
# The total number of unique customers is 4594

# %% [markdown]
# ## `Data Visualization of top 20 customers with the highest purchase using pandas`

# %%
# Top 20 custommers with the highest purchases....
sales["customer_id"].value_counts().sort_values(ascending = False).head(20).plot(kind="bar", figsize= (15, 15),title="top 10 customers with the highest purchase", color = "purple")
# Out:
# <Axes: title={'center': 'top 10 customers with the highest purchase'}, xlabel='customer_id'>

# %%
# selecting a customer to see their behaviour
mask = (sales["customer_id"] == "ebcb2343-be1b-421e-83eb-6f79a321d999")

# %%
# this 
sales[mask].head(1)
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
#
#                    line_item_id                              order_id  \
# location
# Wallis and Futuna         26108  5984596b-0ed5-4571-8e79-b261e6f138ad
#
#                    event_id            event_timestamp  quantity currency  \
# location
# Wallis and Futuna    121373 2024-03-27 12:43:53.991103         5      NGN
#
#                                checked_out_at   status
# location
# Wallis and Futuna  2024-03-30 04:14:16.072620  success

# %%
sales.loc[mask].head(1)
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
#
#                    line_item_id                              order_id  \
# location
# Wallis and Futuna         26108  5984596b-0ed5-4571-8e79-b261e6f138ad
#
#                    event_id            event_timestamp  quantity currency  \
# location
# Wallis and Futuna    121373 2024-03-27 12:43:53.991103         5      NGN
#
#                                checked_out_at   status
# location
# Wallis and Futuna  2024-03-30 04:14:16.072620  success

# %%
# 
sales.loc[mask,"customer_id":"currency"].head(2)
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
#
#                    line_item_id                              order_id  \
# location
# Wallis and Futuna         26108  5984596b-0ed5-4571-8e79-b261e6f138ad
# Wallis and Futuna         26109  5984596b-0ed5-4571-8e79-b261e6f138ad
#
#                    event_id            event_timestamp  quantity currency
# location
# Wallis and Futuna    121373 2024-03-27 12:43:53.991103         5      NGN
# Wallis and Futuna    121373 2024-03-27 12:43:53.991103         1      NGN

# %%
sales["currency"].unique()
# Out:
# array(['NGN', 'USD', 'GBP'], dtype=object)

# %%
currency_and_number_times_used = sales["currency"].value_counts()
currency_and_number_times_used
# Out:
# currency
# USD    198037
# GBP    191403
# NGN    188880
# Name: count, dtype: int64

# %%
currency_and_number_times_used.plot(kind ="bar" ,  figsize =(10, 10,) , title="Currency and number of times used", color = "green")
# Out:
# <Axes: title={'center': 'Currency and number of times used'}, xlabel='currency'>

# %%
# filtering out a specific customer
mask = (sales["customer_id"] == "ebcb2343-be1b-421e-83eb-6f79a321d999")

mask2 = (sales["customer_id"] == "ebcb2343-be1b-421e-83eb-6f79a321d999") & (sales["status"] == "success")

sales.loc[mask2]
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# ...                                                 ...
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        4
# ...

# %%
sales.loc[mask2]
# Out:
#                                             customer_id  \
# location
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# ...                                                 ...
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
# Wallis and Futuna  ebcb2343-be1b-421e-83eb-6f79a321d999
#
#                                               device_id  item_id  \
# location
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        5
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2       11
# Wallis and Futuna  aa3a57b3-6636-4b91-8fa8-56b0524de6c2        4
# ...
